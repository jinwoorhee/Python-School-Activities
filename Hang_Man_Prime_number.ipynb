# %%
#Step 4

import random

stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

end_of_game = False
word_list = ["ardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)
word_length = len(chosen_word)

#TODO-1: - Create a variable called 'lives' to keep track of the number of lives left.
#Set 'lives' to equal 6.
lives = 6

#Testing code
print(f'Pssst, the solution is {chosen_word}.')

#Create blanks
display = []
for _ in range(word_length):
    display += "_"

while not end_of_game:
    guess = input("Guess a letter: ").lower()

    #Check guessed letter
    for position in range(word_length):
        letter = chosen_word[position]
       # print(f"Current position: {position}\n Current letter: {letter}\n Guessed letter: {guess}")
        if letter == guess:
            display[position] = letter

    #TODO-2: - If guess is not a letter in the chosen_word,
    #Then reduce 'lives' by 1.
    #If lives goes down to 0 then the game should stop and it should print "You lose."
    if guess not in chosen_word:
        lives -= 1
        if lives == 0:
            end_of_game = True
            print("You lose.")

    #Join all the elements in the list and turn it into a String.
    print(f"{' '.join(display)}")

    #Check if user has got all letters.
    if "_" not in display:
        end_of_game = True
        print("You win.")

    #TODO-3: - print the ASCII art from 'stages' that corresponds to the current number of 'lives' the user has remaining.
    print(stages[lives])
# Out:
# Pssst, the solution is baboon.
# Guess a letter: a
# _ a _ _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# Guess a letter: b
# b a b _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# Guess a letter: c
# b a b _ _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
# Guess a letter: e
# b a b _ _ _
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# Guess a letter: d
# b a b _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# Guess a letter: f
# b a b _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# ...
#
# Guess a letter: k
# b a b _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# ...
#
# Guess a letter: o
# b a b o o _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# ...
#
# Guess a letter: l
# You lose.
# b a b o o _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# ...

# %%
# Write your code below this line 👇
def prime_checker(number):
  is_prime = True
  for i in range(2, number):
    if number % i == 0:
      is_prime = False
  if is_prime:
    print("It's a prime number.")
  else:
    print("It's not a prime number.")

# Write your code above this line 👆

#Do NOT change any of the code below👇
n = int(input()) # Check this number
prime_checker(number=n)
# Out:
# 1
# It's a prime number.

# %%
student_scores = {
  "Harry": 81,
  "Ron": 78,
  "Hermione": 99,
  "Draco": 74,
  "Neville": 62,
}
# 🚨 Don't change the code above 👆
# TODO-1: Create an empty dictionary called student_grades.
student_grades = {}


# TODO-2: Write your code below to add the grades to student_grades.👇
for student in student_scores:
  score = student_scores[student]
  if score > 91:
    student_grades[student] = 'Outstanding'
  elif score > 80:
    student_grades[student] = 'Exceeds Expectations'
  elif score > 70:
    student_grades[student] = 'Acceptable'
  else:
    student_grades[student] = 'Fail'

# 🚨 Don't change the code below 👇
print(student_grades)
# Out:
# {'Harry': 'Exceeds Expectations', 'Ron': 'Acceptable', 'Hermione': 'Outstanding', 'Draco': 'Acceptable', 'Neville': 'Fail'}

# %%
# Prompt user for country name input
country = input("Enter the name of the country you have visited: ")  # Add country name

# Prompt user for number of visits input
visits = int(input(f"How many times have you visited {country}? "))  # Number of visits

# Prompt user for list of cities visited input
print("Enter the list of cities you visited in the following format: ['City1', 'City2', 'City3']")
list_of_cities = eval(input("Enter cities: "))  # Create list from formatted string

# Existing travel log with predefined data
travel_log = [
  {
    "country": "France",
    "visits": 12,
    "cities": ["Paris", "Lille", "Dijon"]
  },
  {
    "country": "Germany",
    "visits": 5,
    "cities": ["Berlin", "Hamburg", "Stuttgart"]
  },
]

# Function to add a new country to the travel log
def add_new_country(name, times_visited, cities_visited):
  new_country = {
    "country": name,
    "visits": times_visited,
    "cities": cities_visited
  }
  travel_log.append(new_country)

# Adding a new country based on user input
add_new_country(country, visits, list_of_cities)

# Display the result
print(f"I've been to {travel_log[-1]['country']} {travel_log[-1]['visits']} times.")
print(f"My favourite city was {travel_log[-1]['cities'][0]}.")
# Out:
# Enter the name of the country you have visited: Germany
# How many times have you visited Germany? 5
# Enter the list of cities you visited in the following format: ['City1', 'City2', 'City3']
# Enter cities: "Berlin", "Hamburg", "Stuttgart"
# I've been to Germany 5 times.
# My favourite city was Berlin.
